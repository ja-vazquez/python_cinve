# %% [markdown]
# # Numeros Complejos

# %% [markdown]
# ## Operaciones elementales

# %% [markdown]
# ### El paquete

# %%
import cmath as cm

# %% [markdown]
# #### Fase, norma, forma polar, forma rectangular

# %%
z = complex(-5,1)
z2 = complex('-8+2j')

z / z2
# Out:
# (0.6176470588235294+0.029411764705882353j)

# %%
z+ z2
# Out:
# (-13+3j)

# %%
cm.polar(complex('j'))
# Out:
# (1.0, 1.5707963267948966)

# %%
cm.phase(z)
# Out:
# 2.9441970937399127

# %%
abs(z)
# Out:
# 5.0990195135927845

# %%
r = abs(z)
phi = cm.phase(z)
cm.rect(r, phi)
# Out:
# (-5+0.999999999999999j)

# %% [markdown]
# ### Funciones trigonométicas, exp, log

# %%
cm.sin(z)
# Out:
# (1.4796974784869428+0.3333601389479928j)

# %%
cm.tanh(z)
# Out:
# (-1.0000377833796008+8.256719834229595e-05j)

# %%
cm.exp(z)
# Out:
# (0.0036405283004231903+0.005669786896903859j)

# %%
cm.log(z)
# Out:
# (1.6290482690107408+2.9441970937399127j)

# %%
cm.pi
# Out:
# 3.141592653589793

# %%
cm.e
# Out:
# 2.718281828459045

# %% [markdown]
# ## Plots

# %%
import numpy as n
from matplotlib.pyplot import *

# %%
a = n.arange(5) + 1j*n.arange(6,11)

# %%
a
# Out:
# array([ 0. +6.j,  1. +7.j,  2. +8.j,  3. +9.j,  4.+10.j])

# %%
fig,ax = subplots()
ax.scatter(a.real,a.imag)
show()

# %%
for x in a:
    polar([0,cm.phase(x)],[0,abs(x)],marker='o')
show()

# %%
from scipy import special
def drumhead_height(n, k, distance, angle, t):
    kth_zero = special.jn_zeros(n, k)[-1]
    return np.cos(t) * np.cos(n*angle) * special.jn(n, distance*kth_zero)
theta = np.r_[0:2*np.pi:50j]
radius = np.r_[0:1:50j]
x = np.array([r * np.cos(theta) for r in radius])
y = np.array([r * np.sin(theta) for r in radius])
z = np.array([drumhead_height(1, 1, r, theta, 0.5) for r in radius])

# %%
special.jn_zeros

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
fig = plt.figure()
ax = Axes3D(fig)
ax.plot_surface(x, y, z, rstride=1, cstride=1, cmap=cm.jet)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.show()

# %%
fucn = [lambda: x, x+1, lambda: x, x+2]
