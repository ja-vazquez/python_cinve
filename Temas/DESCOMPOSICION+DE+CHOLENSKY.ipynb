# %% [markdown]
# # Descomposición de Cholesky

# %%
import numpy as np
#Para matrices (A) simétricas y definidas positivas,
#podemos hallar una matriz triangular (L) tal que A=L*Lt

# %%
A=[[1.,2.,3.],[2.,8.,4.],[3.,4.,11.]]

# %%
print (A)
# Out:
# [[1.0, 2.0, 3.0], [2.0, 8.0, 4.0], [3.0, 4.0, 11.0]]

# %%
At=np.transpose(A)

# %%
print (At)
# Out:
# [[  1.   2.   3.]
#  [  2.   8.   4.]
#  [  3.   4.  11.]]

# %%
A==At
# Out:
# array([[ True,  True,  True],
#        [ True,  True,  True],
#        [ True,  True,  True]], dtype=bool)

# %%
np.linalg.det(A)>0
# Out:
# True

# %%
L=np.linalg.cholesky(A)

# %%
print (L)
# Out:
# [[ 1.  0.  0.]
#  [ 2.  2.  0.]
#  [ 3. -1.  1.]]

# %%
Lt=np.transpose(L)

# %%
print (Lt)
# Out:
# [[ 1.  2.  3.]
#  [ 0.  2. -1.]
#  [ 0.  0.  1.]]

# %%
M=np.dot(L,Lt)

# %%
print (M)
# Out:
# [[  1.   2.   3.]
#  [  2.   8.   4.]
#  [  3.   4.  11.]]

# %%
A==M
# Out:
# array([[ True,  True,  True],
#        [ True,  True,  True],
#        [ True,  True,  True]], dtype=bool)

# %%
B=[[0.,-2,4],[2.,0.,2.],[-4.,-2.,0.]]

# %%
print (B)
# Out:
# [[0.0, -2, 4], [2.0, 0.0, 2.0], [-4.0, -2.0, 0.0]]

# %%
k=np.linalg.cholesky(B)
# B es una matriz antisimétrica, determinante igual a 0
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-70-290b0b3e22cb> in <module>()
# ----> 1 k=np.linalg.cholesky(B)
#       2 # B es una matriz antisimétrica, determinante igual a 0
#
# ~\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in cholesky(a)
#     597     t, result_t = _commonType(a)
#     598     signature = 'D->D' if isComplexType(t) else 'd->d'
# --> 599     r = gufunc(a, signature=signature, extobj=extobj)
#     600     return wrap(r.astype(result_t, copy=False))
#     601
#
# ~\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in _raise_linalgerror_nonposdef(err, flag)
#      91
#      92 def _raise_linalgerror_nonposdef(err, flag):
# ---> 93     raise LinAlgError("Matrix is not positive definite")
#      94
#      95 def _raise_linalgerror_eigenvalues_nonconvergence(err, flag):
#
# LinAlgError: Matrix is not positive definite

# %%
C=[[3,-2,-5,4],[-5,2,8,-5],[-2,4,7,-3],[2,-3,-5,8]]

# %%
print (np.linalg.det(C))
# Out:
# -54.0

# %%
L=np.linalg.cholesky(C)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-75-2f0211c60d70> in <module>()
# ----> 1 L=np.linalg.cholesky(C)
#
# ~\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in cholesky(a)
#     597     t, result_t = _commonType(a)
#     598     signature = 'D->D' if isComplexType(t) else 'd->d'
# --> 599     r = gufunc(a, signature=signature, extobj=extobj)
#     600     return wrap(r.astype(result_t, copy=False))
#     601
#
# ~\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in _raise_linalgerror_nonposdef(err, flag)
#      91
#      92 def _raise_linalgerror_nonposdef(err, flag):
# ---> 93     raise LinAlgError("Matrix is not positive definite")
#      94
#      95 def _raise_linalgerror_eigenvalues_nonconvergence(err, flag):
#
# LinAlgError: Matrix is not positive definite

# %%
P=[[2,1,1],[0,5,-2],[1,-3,4]]

# %%
Pt=np.transpose(P)

# %%
P==Pt
# Out:
# array([[ True, False,  True],
#        [False,  True, False],
#        [ True, False,  True]], dtype=bool)

# %%
print (np.linalg.det(P))
# Out:
# 21.0

# %%
g=np.linalg.cholesky(P)

# %%
print (g)
# Out:
# [[ 1.41421356  0.          0.        ]
#  [ 0.          2.23606798  0.        ]
#  [ 0.70710678 -1.34164079  1.30384048]]
